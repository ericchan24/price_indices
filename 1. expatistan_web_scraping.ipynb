# %%
import requests
from bs4 import BeautifulSoup
import re
from collections import defaultdict
import pandas as pd
import numpy as np
import pickle

# %%
print("Pandas version:",pd.__version__)
print("Numpy version:",np.__version__)
# Out:
# Pandas version: 1.2.4
# Numpy version: 1.20.1

# %% [markdown]
# 1. Get links, **`link=get_links()`**
# 2. create dictionary
# Begin Loop
# 3. Create soup object, **`soup=create_soup_object(url)`** *
# 4. Find city and put in dictionary, **`find_city_put_in_dict(input_dict)`**
# 5. Get items and put in list **`items=get_items()`**
# 6. Get prices and put in list **`prices=get_prices()`**
# 7. Put items and prices in dictionary  **`items_prices_to_dict(cities_dict)`**
# 8. Get price index
# 9. Put price index in dictionary
# 10. Make data frame **`cities_df = make_df(input_dict)`**

# %%
def get_links():
    '''
    output: a list of all the links on the expatistan website
    '''
    links = []
    for line in soup.find_all('td', class_='city-name'):
        links.append(line.find('a')['href'])
    return links

# %%
def create_soup_object(url):
    '''
    input: url
    output: soup object of url text
    '''
    response = requests.get(url)
    if response.status_code == 200:
        page = response.text
    soup = BeautifulSoup(page, 'html5lib')
    return soup

# %%
def find_city_put_in_dict(input_dict):
    '''
    finds the city in the expatistan website and puts it in input_dict
    '''
    city = soup.find('span', class_='city-2').text
    input_dict['City'].append(city)

# %%
def get_items():
    '''
    finds all the item names used in the cost of living index on the expatistan website
    returns a list of items
    '''
    items = []
    for row in soup.find_all('td', class_='item-name'):
        item = row.find('a').text
        items.append(item)
    return items

# %%
def get_price_indices():
    '''
    soup object must be initialized on https://www.expatistan.com/cost-of-living/index page
    output: the price indices on the expatistan website
    '''
    price_index = []
    for row in soup.find_all('td', class_ ='price-index'):
        item = row.text
        price_index.append(item)
    return price_index

# %%
def get_prices():
    '''
    returns a list of prices from scraped from the expatistan website
    '''
    prices = []
    price_regex = re.compile(r'\(?\$?([0-9,.]*)|([-])')
    for row in soup.find_all('td', class_='price city-1'):
        row=row.text.strip()
        mo = price_regex.search(row)
        if mo:
            prices.append(mo.group(1))

    if len(prices) == 104:
        prices1 = prices[1::2]
    else:
        prices1 = prices
    return prices1

# %%
def items_prices_to_dict(input_dict):
    '''
    takes items and prices and puts them to input_dict
    '''
    for item, price in zip(items, prices):
        input_dict[item].append(price)

# %%
url = 'https://www.expatistan.com/cost-of-living/index'
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
page = response.text

# %%
soup = BeautifulSoup(page,"html5lib")

# %%
cities_dict = defaultdict(list) 
url = 'https://www.expatistan.com/cost-of-living/index'
soup = create_soup_object(url)
links = get_links()
price_indices = get_price_indices()
for i,url in enumerate(links):
    url=url+'?currency=USD'
    print(i, url)
    soup = create_soup_object(url)
    find_city_put_in_dict(cities_dict)
    items = get_items()
    prices = get_prices()
    items_prices_to_dict(cities_dict)
# Out:
# 0 https://www.expatistan.com/cost-of-living/zurich?currency=USD
# 1 https://www.expatistan.com/cost-of-living/grand-cayman?currency=USD
# 2 https://www.expatistan.com/cost-of-living/san-francisco?currency=USD
# 3 https://www.expatistan.com/cost-of-living/new-york-city?currency=USD
# 4 https://www.expatistan.com/cost-of-living/london?currency=USD
# 5 https://www.expatistan.com/cost-of-living/geneva?currency=USD
# 146 https://www.expatistan.com/cost-of-living/delhi?currency=USD
# 147 https://www.expatistan.com/cost-of-living/asuncion?currency=USD
# 148 https://www.expatistan.com/cost-of-living/medellin?currency=USD
# 149 https://www.expatistan.com/cost-of-living/bangalore?currency=USD
# 150 https://www.expatistan.com/cost-of-living/cairo?currency=USD
# 151 https://www.expatistan.com/cost-of-living/barranquilla?currency=USD
# 152 https://www.expatistan.com/cost-of-living/baku?currency=USD
# 153 https://www.expatistan.com/cost-of-living/almaty?currency=USD
# 154 https://www.expatistan.com/cost-of-living/santiago-de-cali?currency=USD
# 155 https://www.expatistan.com/cost-of-living/arequipa?currency=USD
# 156 https://www.expatistan.com/cost-of-living/bucaramanga?currency=USD
# 157 https://www.expatistan.com/cost-of-living/pune?currency=USD
# 158 https://www.expatistan.com/cost-of-living/istanbul?currency=USD
# 159 https://www.expatistan.com/cost-of-living/ankara?currency=USD
# 160 https://www.expatistan.com/cost-of-living/izmir?currency=USD

# %% [markdown]
# ### Create df with scraped data
# #### Data for project was scraped on Jan 12, 2022

# %%
cities_df = pd.DataFrame.from_dict(cities_dict)
cities_df['Price_Index'] = price_indices
pi = cities_df['Price_Index'] 
cities_df.drop(labels=['Price_Index'], axis=1,inplace = True) 
cities_df.insert(0, 'Price_Index', pi) # move "Price_Index" column to front
cities_df.set_index(['City'], inplace=True)
cities_df.head()
# Out:
#                                          Price_Index  \
# City
# Zurich, Switzerland                              255
# Grand Cayman, Cayman Islands                     253
# San Francisco, California, United States         239
# New York City, United States                     238
# London, United Kingdom                           238
#
#                                          Basic lunchtime menu (including a drink) in the business district  \
# City
# Zurich, Switzerland                                                                      29
# Grand Cayman, Cayman Islands                                                             19
# San Francisco, California, United States                                                 20
# New York City, United States                                                             19
# London, United Kingdom                                                                   17
#
#                                          Combo meal in fast food restaurant (big mac meal or similar)  \
# City
# Zurich, Switzerland                                                                      15
# Grand Cayman, Cayman Islands                                                             10
# San Francisco, California, United States                                                 10
# New York City, United States                                                              9
# London, United Kingdom                                                                    8
#
#                                          500 gr (1 lb.) of boneless chicken breast  \
# City
# Zurich, Switzerland                                                             12
# Grand Cayman, Cayman Islands                                                     6
# San Francisco, California, United States                                         7
# New York City, United States                                                     6
# London, United Kingdom                                                        5.18
#
#                                          1 liter (1 qt.) of whole fat milk  \
# City
# Zurich, Switzerland                                                   1.98
# Grand Cayman, Cayman Islands                                          3.21
# San Francisco, California, United States                              1.23
# New York City, United States                                          1.11
# London, United Kingdom                                                1.31
#
#                                          12 eggs, large  \
# City
# Zurich, Switzerland                                   8
# Grand Cayman, Cayman Islands                       5.63
# San Francisco, California, United States           4.46
# New York City, United States                       3.63
# London, United Kingdom                             3.76
#
#                                          1 kg (2 lb.) of tomatoes  \
# City
# Zurich, Switzerland                                          3.88
# Grand Cayman, Cayman Islands                                    8
# San Francisco, California, United States                        7
# New York City, United States                                 4.62
# London, United Kingdom                                       2.69
#
#                                          500 gr (16 oz.) of local cheese  \
# City
# Zurich, Switzerland                                                   10
# Grand Cayman, Cayman Islands                                           8
# San Francisco, California, United States                               7
# New York City, United States                                           7
# London, United Kingdom                                                 7
#
#                                          1 kg (2 lb.) of apples  \
# City
# Zurich, Switzerland                                        3.80
# Grand Cayman, Cayman Islands                                  7
# San Francisco, California, United States                      6
# New York City, United States                               3.73
# London, United Kingdom                                     3.07
#
#                                          1 kg (2 lb.) of potatoes  ...  \
# City                                                               ...
# Zurich, Switzerland                                          2.58  ...
# Grand Cayman, Cayman Islands                                 3.67  ...
# San Francisco, California, United States                     1.63  ...
# New York City, United States                                 1.59  ...
# London, United Kingdom                                       1.12  ...
#
#                                          2 tickets to the movies  \
# City
# Zurich, Switzerland                                           36
# Grand Cayman, Cayman Islands                                  33
# San Francisco, California, United States                      30
# New York City, United States                                  31
# London, United Kingdom                                        33
#
#                                          2 tickets to the theater (best available seats)  \
# City
# Zurich, Switzerland                                                                  283
# Grand Cayman, Cayman Islands                                                          56
# San Francisco, California, United States                                             263
# New York City, United States                                                         397
# London, United Kingdom                                                               293
#
#                                          Dinner for two at an italian restaurant in the expat area including appetisers, main course, wine and dessert  \
# City
# Zurich, Switzerland                                                                     105
# Grand Cayman, Cayman Islands                                                            106
# San Francisco, California, United States                                                 94
# New York City, United States                                                            113
# London, United Kingdom                                                                  101
#
#                                          1 cocktail drink in downtown club  \
# City
# Zurich, Switzerland                                                     18
# Grand Cayman, Cayman Islands                                            13
# San Francisco, California, United States                                14
# New York City, United States                                            17
# London, United Kingdom                                                  15
#
#                                          Cappuccino in expat area of the city  \
# City
# Zurich, Switzerland                                                      5.63
# Grand Cayman, Cayman Islands                                                6
# San Francisco, California, United States                                 4.79
# New York City, United States                                             5.12
# London, United Kingdom                                                   4.53
#
#                                          1 beer in neighbourhood pub (500ml or 1pt.)   \
# City
# Zurich, Switzerland                                                                 8
# Grand Cayman, Cayman Islands                                                        7
# San Francisco, California, United States                                            7
# New York City, United States                                                        7
# London, United Kingdom                                                              8
#
#                                          Ipad wi-fi 128gb  \
# City
# Zurich, Switzerland                                   536
# Grand Cayman, Cayman Islands                          635
# San Francisco, California, United States              426
# New York City, United States                          423
# London, United Kingdom                                683
#
#                                          1 min. of prepaid mobile tariff (no discounts or plans)  \
# City
# Zurich, Switzerland                                                                    0.44
# Grand Cayman, Cayman Islands                                                           0.41
# San Francisco, California, United States                                               0.14
# New York City, United States                                                           0.48
# London, United Kingdom                                                                 0.47
#
#                                          1 month of gym membership in business district  \
# City
# Zurich, Switzerland                                                                 131
# Grand Cayman, Cayman Islands                                                         79
# San Francisco, California, United States                                             83
# New York City, United States                                                         74
# London, United Kingdom                                                               66
#
#                                          1 package of marlboro cigarettes
# City
# Zurich, Switzerland                                                     9
# Grand Cayman, Cayman Islands                                           12
# San Francisco, California, United States                               12
# New York City, United States                                           14
# London, United Kingdom                                                 17
#
# [5 rows x 53 columns]

# %%
cities_df.replace('', np.nan , inplace = True) # replace blank values with nan

# get all the object columns, replace ',' with '.'
obj_cols = cities_df.select_dtypes(include=['object']).columns
for col in obj_cols:
    cities_df[col] = cities_df[col].str.replace(',', '').astype(float)

# %% [markdown]
# # Save df as csv

# %%
cities_df.to_csv('price_indicies.csv')
